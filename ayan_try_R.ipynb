# %% [markdown]
# <a href="https://colab.research.google.com/github/adgcal/Anjan_collab_R/blob/main/ayan_try_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Anjan K Dasgupta JU R Course 2021

# %%
print(installed.packages())
# Out:
#               Package         LibPath                         Version
# IRdisplay     "IRdisplay"     "/usr/local/lib/R/site-library" "1.0"
# IRkernel      "IRkernel"      "/usr/local/lib/R/site-library" "1.2"
# pbdZMQ        "pbdZMQ"        "/usr/local/lib/R/site-library" "0.3-5"
# repr          "repr"          "/usr/local/lib/R/site-library" "1.1.3"
# askpass       "askpass"       "/usr/lib/R/site-library"       "1.1"
# assertthat    "assertthat"    "/usr/lib/R/site-library"       "0.2.1"
# backports     "backports"     "/usr/lib/R/site-library"       "1.2.1"
# base64enc     "base64enc"     "/usr/lib/R/site-library"       "0.1-3"
# bit           "bit"           "/usr/lib/R/site-library"       "4.0.4"
# bit64         "bit64"         "/usr/lib/R/site-library"       "4.0.5"
# blob          "blob"          "/usr/lib/R/site-library"       "1.2.2"
# brew          "brew"          "/usr/lib/R/site-library"       "1.0-6"
# ...

# %%
install.packages("plyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("tm")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘NLP’, ‘slam’, ‘BH’

# %%
install.packages("psych")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘tmvnsim’, ‘mnormt’

# %%
install.packages("readxl")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("devtools")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(devtools)
# Out:
# Loading required package: usethis

# %%
install.packages("nnet")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("neuralnet")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘Deriv’

# %%
install.packages("ROCR")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘bitops’, ‘gtools’, ‘caTools’, ‘gplots’

# %%
install.packages("rpart")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
x<-c("plyr", "psych","slam","tm","readxl","nnet","neuralnet","ROCR","rpart")
lapply(x, FUN = function(X) {
    do.call("require", list(X)) 
})
# Out:
# Loading required package: plyr
#
# Loading required package: psych
#
# Loading required package: slam
#
# Loading required package: tm
#
# Loading required package: NLP
#
# Loading required package: readxl
#
# Loading required package: nnet
#
# Loading required package: neuralnet
#
# Loading required package: ROCR
#
#
# Attaching package: ‘ROCR’
#
#
# The following object is masked from ‘package:neuralnet’:
#
#     prediction
#
#
# Loading required package: rpart
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE
#
# [[4]]
# [1] TRUE
#
# [[5]]
# [1] TRUE
#
# [[6]]
# [1] TRUE
#
# [[7]]
# [1] TRUE
#
# [[8]]
# [1] TRUE
#
# [[9]]
# [1] TRUE

# %%
z1<-read_xlsx('./sample_data/T.xlsx')
z2<-read_xlsx("./sample_data/cont.xlsx")# describe file
z3<-read_xlsx("./sample_data/contp.xlsx")# describe file
CSFS<-data.frame(z2,z3[,-1])

# %% [markdown]
# z4<-read_xls("./sample_data/USFS.xls")# describe file
# z5<-read_xls("./sample_data/U2SFS.xls")# describe file
# z6<-read_xls("./sample_data/U3SFS.xls")# describe file
# z7<-read.csv("./sample_data/u4sfs.csv")# describe file
# USFS<-data.frame(z4,z5[,-1],z6[,-1],z7[,-1])

# %%
plot(z1$wavelen,z1$T1,type="l")
# Out:
# plot without title

# %% [markdown]
# # New Section

# %% [markdown]
# <http://rstudio-pubs-static.s3.amazonaws.com/311446_08b00d63cc794e158b1f4763eb70d43a.html>

# %%
data("AirPassengers")
#AP <- AirPassengers
sp <- spectrum(log(AirPassengers), span = c(3, 5))
class(sp)
# Out:
# [1] "spec"
# Plot with title “Series: x
# Smoothed Periodogram”

# %%
install.packages("pryr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘lobstr’

# %%
library(pryr)

# %%
otype(sp)
# Out:
# [1] "S3"

# %%
plot(sp$freq,sp$spec,type="l")
# Out:
# plot without title

# %%
x <- sp$freq
y <- log(sp$spec)
plot(x,y,type='l')

# %%
f <- function(x, q, d) spline(q, d, xout = x)$y
x <- sp$freq
y <- log(sp$spec)
plot(x,y,type='l')
# Out:
# plot without title

# %% [markdown]
# ## QUESTION
# - How to deal with spec class of object ?
# - What is a peridogram of a time series?

# %%
class(AP)
# Out:
# [1] "ts"

# %%
# objective function, spline interpolation of the sample spectrum
f <- function(x, q, d) spline(q, d, xout = x)$y
x <- sp$freq
y <- log(sp$spec)
nb <- 10 # choose number of intervals
iv <- embed(seq(floor(min(x)), ceiling(max(x)), len = nb), 2)[,c(2,1)]
# make overlapping intervals to avoid problems if the peak is close to 
# the ends of the intervals (two modes could be found in each interval)
iv[-1,1] <- iv[-nrow(iv),2] - 2
# The function "f" is maximized at each of these intervals
iv
# Out:
#       [,1]       [,2]
#  [1,]  0.0000000 0.6666667
#  [2,] -1.3333333 1.3333333
#  [3,] -0.6666667 2.0000000
#  [4,]  0.0000000 2.6666667
#  [5,]  0.6666667 3.3333333
#  [6,]  1.3333333 4.0000000
#  [7,]  2.0000000 4.6666667
#  [8,]  2.6666667 5.3333333
#  [9,]  3.3333333 6.0000000

# %%
install.packages("numDeriv")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(numDeriv)

# %%
gr.thr <- 0.001
hes.thr <- 0.03
vals <- matrix(nrow = nrow(iv), ncol = 3)
grd <- hes <- rep(NA, nrow(vals))
for (j in seq(1, nrow(iv)))
{
  opt <- optimize(f = f, maximum = TRUE, interval = iv[j,], q = x, d = y)
  vals[j,1] <- opt$max
  vals[j,3] <- exp(opt$obj)
  grd[j] <- grad(func = f, x = vals[j,1], q = x, d = y)
  hes[j] <- hessian(func = f, x = vals[j,1], q = x, d = y)
  if (abs(grd[j]) < gr.thr && abs(hes[j]) > hes.thr)
    vals[j,2] <- 1
}
# it is convenient to round the located peaks in order to avoid
# several local maxima that essentially the same point
vals[,1] <- round(vals[,1], 2)
if (anyNA(vals[,2])) {
  peaks <- unique(vals[-which(is.na(vals[,2])),1])
} else 
  peaks <- unique(vals[,1])

  peaks
# Out:
# [1] 0.06 1.00 2.01 2.99 4.00 4.98

# %%
plot(sp$freq, sp$spec, log = "y", type = "l")
abline(v = peaks, lty = 2)
# Out:
# plot without title
